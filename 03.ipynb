# %%
# Import lớp Image
from PIL import Image
from imgtools import *
from IPython.display import display # to display images

# %%
dir = 'C:/Users/Tokisaki/Pictures/Saved Pictures/ark.jpg'

# %%
# Đọc ảnh 
img = load_image(dir)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1623x1256>

# %%
# Kích thước ban đầu:
print(img.size)
# Out:
# (1623, 1256)

# %%
# Thay đổi kích thước
new_size = (1000,1000)
new_image = img.resize(new_size)
display(new_image)
# Task: lưu ảnh
new_img_ark_path = dir + '/new_ark.jpg'
img.save(new_img_ark_path)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x1000>
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 7
#       5 # Task: lưu ảnh
#       6 new_img_ark_path = dir + '/new_ark.jpg'
# ----> 7 img.save(new_img_ark_path)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\PIL\Image.py:2563, in Image.save(self, fp, format, **params)
#    2561         fp = builtins.open(filename, "r+b")
#    2562     else:
# -> 2563         fp = builtins.open(filename, "w+b")
#    2564 else:
#    2565     fp = cast(IO[bytes], fp)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\Tokisaki\\Pictures\\Saved Pictures\\ark.jpg\\new_ark.jpg'

# %%
# Thay đổi kích thước
thumbnail_size = (50,50)
img.thumbnail(thumbnail_size)
display(img)
# Task: lưu ảnh
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=50x39>

# %%
new_img_ark_path = dir + '/new_ark.JPG'
new_img_png_ark_path = dir + '/new_ark.PNG'
img01.save(new_img_ark_path)
img01.save(new_img_png_ark_path)
