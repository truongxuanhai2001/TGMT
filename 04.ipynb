# %%
# Import lớp Image
from PIL import Image
from imgtools import *
from IPython.display import display

# %%
my_path = 'C:/Users/Tokisaki/Pictures/Saved Pictures/boi.png'

# %%
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1057x667>

# %%
# Định vị khu vực cắt
region = (100, 100, 175, 160)
# Cắt vùng ảnh
cropped_image = img.crop(region)
display(cropped_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=75x60>

# %%
paste_position = (150, 150)
img.paste(cropped_image, paste_position)
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1057x667>
