# %%
#!pip install Pillow

# %%
from PIL import Image

# %%
dir = 'C:/Users/Tokisaki/Pictures/Saved Pictures'

# %%
image_path = dir +'/ark.jpg'
print(image_path)
# Out:
# C:/Users/Tokisaki/Pictures/Saved Pictures/ark.jpg

# %%
img01 = Image.open(image_path)

# %%
display(img01)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1623x1256>

# %%
print("Định dang ảnh: ", img01.format)
# Out:
# Định dang ảnh:  JPEG

# %%
print("Kích thước hình ảnh: ", img01.size)
# Out:
# Kích thước hình ảnh:  (1623, 1256)

# %%
new_img_ark_path = dir + '/new_ark.JPG'
new_img_png_ark_path = dir + '/new_ark.PNG'
img01.save(new_img_ark_path)
img01.save(new_img_png_ark_path)

# %%
img01.close()
