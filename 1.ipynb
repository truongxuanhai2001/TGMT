# %%
print("hi")
# Out:
# hi

# %%
pip install Keras-Preprocessing
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 from tensorflow.keras.preprocessing.image import ImageDataGenerator
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tensorflow\__init__.py:38
#      35 import sys as _sys
#      37 # Do not remove this line; See https://github.com/tensorflow/tensorflow/issues/42596
# ---> 38 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow  # pylint: disable=unused-import
#      39 from tensorflow.python.tools import module_util as _module_util
#      40 from tensorflow.python.util.lazy_loader import KerasLazyLoader as _KerasLazyLoader
#
# ModuleNotFoundError: No module named 'tensorflow.python'

# %%
# !pip install Pillow
# !conda install Pillow
# Out:
# ...
# 'conda' is not recognized as an internal or external command,
# operable program or batch file.

# %%
from PIL import Image

# %%
dir = 'E:/TGMT/anh'

# %%
image_path = dir +'/1.JPG'
print(image_path)
# Out:
# E:/TGMT/anh/1.JPG

# %%
anh1 =  Image.open(image_path)

# %%
display(anh1)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=683x1200>

# %%
print("Định dang ảnh: ", anh1.format)
# Out:
# Định dang ảnh:  <built-in method format of str object at 0x00000253D9660830>

# %%
print("Kích thước hình ảnh: ", anh1.size)
# Out:
# Kích thước hình ảnh:  (683, 1200)

# %%
new_anh_01_path = dir + '/new_01.JPG'
new_anh_png_01_path = dir + '/new_01.PNG'
anh1.save(new_anh_01_path)
anh1.save(new_img_png_01_path)

# %%
anh1.close()
